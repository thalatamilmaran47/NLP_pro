# %% [markdown]
# <a href="https://colab.research.google.com/github/thalatamilmaran47/NLP_pro/blob/main/Nlp_pro_9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from textblob import TextBlob
import pandas as pd

data = {
    "Review": [
        "I love this product, it is amazing",
        "The service was very bad",
        "Average experience, nothing special",
        "Excellent quality and great support",
        "Worst experience ever"
    ]
}

df = pd.DataFrame(data)

df["Review"] = df["Review"].str.lower()

df["Polarity"] = df["Review"].apply(lambda x: TextBlob(x).sentiment.polarity)
df["Subjectivity"] = df["Review"].apply(lambda x: TextBlob(x).sentiment.subjectivity)

def classify_sentiment(polarity):
    if polarity > 0:
        return "Positive"
    elif polarity < 0:
        return "Negative"
    else:
        return "Neutral"

df["Sentiment"] = df["Polarity"].apply(classify_sentiment)

print("Overall Sentiment Count:")
print(df["Sentiment"].value_counts())

df.to_csv("sentiment_analysis_results.csv", index=False)
print("Sentiment analysis results saved successfully.")
# Out:
# Overall Sentiment Count:
# Sentiment
# Positive    3
# Negative    2
# Name: count, dtype: int64
# Sentiment analysis results saved successfully.
