# %% [markdown]
# <a href="https://colab.research.google.com/github/thalatamilmaran47/NLP_pro/blob/main/Nlp_pro_10.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import re
import random

responses = {
    r'hi|hello|hey': [
        "Hello! How can I help you?",
        "Hi there! What can I do for you?"
    ],
    r'how are you': [
        "I'm doing well, thank you!",
        "I'm fine! How about you?"
    ],
    r'what is your name': [
        "I am a rule-based chatbot.",
        "You can call me ChatBot!"
    ],
    r'bye|exit|quit': [
        "Goodbye! Have a great day!",
        "Bye! See you soon."
    ]
}

def chatbot():
    print("Chatbot: Hello! Type 'bye' to exit.")
    while True:
        user_input = input("You: ").lower()
        matched = False

        for pattern, reply in responses.items():
            if re.search(pattern, user_input):
                print("Chatbot:", random.choice(reply))
                matched = True
                if re.search(r'bye|exit|quit', user_input):
                    return

        if not matched:
            print("Chatbot: Sorry, I didn't understand that.")

chatbot()
# Out:
# Chatbot: Hello! Type 'bye' to exit.
# Chatbot: Sorry, I didn't understand that.
# You:
# Chatbot: Sorry, I didn't understand that.
