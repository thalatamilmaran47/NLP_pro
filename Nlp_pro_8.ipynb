# %% [markdown]
# <a href="https://colab.research.google.com/github/thalatamilmaran47/NLP_pro/blob/main/Nlp_pro_8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import MultinomialNB
from sklearn.metrics import accuracy_score
import pickle

data = {
    "Text": [
        "Win a free mobile now",
        "Limited offer claim prize",
        "Meeting scheduled tomorrow",
        "Let us discuss the project",
        "Congratulations you won cash",
        "Lunch at 1 pm today"
    ],
    "Label": ["Spam", "Spam", "Ham", "Ham", "Spam", "Ham"]
}

df = pd.DataFrame(data)

df["Text"] = df["Text"].str.lower()

vectorizer = CountVectorizer()
X = vectorizer.fit_transform(df["Text"])
y = df["Label"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y, test_size=0.3, random_state=42
)

model = MultinomialNB()
model.fit(X_train, y_train)

y_pred = model.predict(X_test)

accuracy = accuracy_score(y_test, y_pred)
print("Accuracy:", accuracy)

print("\nActual Labels:")
print(list(y_test))

print("\nPredicted Labels:")
print(list(y_pred))

with open("text_classifier_model.pkl", "wb") as file:
    pickle.dump(model, file)

print("\nTrained model saved successfully.")
# Out:
# Accuracy: 0.0
#
# Actual Labels:
# ['Spam', 'Spam']
#
# Predicted Labels:
# [np.str_('Ham'), np.str_('Ham')]
#
# Trained model saved successfully.
